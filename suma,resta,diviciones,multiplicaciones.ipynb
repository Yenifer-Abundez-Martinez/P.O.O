# %%
rint("... EJERCICIO ...")
print("")
print("")
print("---10 SUMAS---")
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1+n2
print(n1, "+", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1+n2
print(n1, "+", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1+n2
print(n1, "+", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1+n2
print(n1, "+", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1+n2
print(n1, "+", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1+n2
print(n1, "+", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1+n2
print(n1, "+", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1+n2
print(n1, "+", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1+n2
print(n1, "+", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1+n2
print(n1, "+", n2, "=", r)
print("")
print("")

# %%
print("---10 RESTAS---")
print("")
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1-n2
print(n1, "-", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1-n2
print(n1, "-", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1-n2
print(n1, "-", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1-n2
print(n1, "-", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1-n2
print(n1, "-", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1-n2
print(n1, "-", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1-n2
print(n1, "-", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1-n2
print(n1, "-", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1-n2
print(n1, "-", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1-n2
print(n1, "-", n2, "=", r)
print("")
print("")
# Out:
# ---10 RESTAS---
#
#
# 2 - 1 = 1

# %%
print("---10 MULTIPLICACIONES---")
print("")
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1*n2
print(n1, "*", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1*n2
print(n1, "*", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1*n2
print(n1, "*", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1*n2
print(n1, "*", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1*n2
print(n1, "*", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1*n2
print(n1, "*", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1*n2
print(n1, "*", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1*n2
print(n1, "*", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1*n2
print(n1, "*", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1*n2
print(n1, "*", n2, "=", r)
print("")
print("")

# %%
print("")print("---10 DIVISIONES---")
print("")
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1/n2
print(n1, "/", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1/n2
print(n1, "/", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1/n2
print(n1, "/", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1/n2
print(n1, "/", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1/n2
print(n1, "/", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1/n2
print(n1, "/", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1/n2
print(n1, "/", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1/n2
print(n1, "/", n2, "=", r)
print("")
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
n1=int(input("Ingrese el número 1:"))
n2=int(input("Ingrese el número 2:"))
r=n1/n2
print(n1, "/", n2, "=", r)
print("")
