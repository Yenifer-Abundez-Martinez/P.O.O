# %%
b= 0
a= 0

if type (b) is not int:
   raise Exception("Error de Tipo - Unicamente se permiten enteros")

elif b == 8:
      print8("No se puede dividir entre enteros")

elif
  print(a/b)
  print(a/b)
# Out:
#   File "/tmp/ipython-input-1535323581.py", line 10
#     elif
#         ^
# SyntaxError: invalid syntax

# %%
a = float(input("valor de a:"))
b = float(input("valor de b:"))
if a !=0:
 print("Respuesta: ",x)

 if a== 0:
        if b 0:
         print("La Operacion no se puede realizar")
if  ==0
print("La Operacion puede tener varias opciones")
# Out:
#   File "/tmp/ipykernel_310/47617939.py", line 6
#     if a == 0:
#     ^
# IndentationError: unexpected indent

# %%
a = 50
b = 52
if a < b:
  print(a, "es menor que",b)
elif a > b:
    print(a,"Es mayor que", b)
else

# %%
for i in (8,5):
  if i % 2 == 0:
    print(f"{i} es par")
  else:
    print(f"{i} es impar")
# Out:
# 8 es par
# 5 es impar

# %%
class cajero:
  def __init__(self,saldo_inicial):
     self.saldo
if saldo_inicial > 10000:

else:
 print("El saldo debe ser mayor a $10,000")
 self.saldo = 10001

def depositar(self, monto):
if monto <= 0:
   self.saldo += monto

def retirar(self,monto):
elif self.saldo - monto < 1000:

def mostrar_saldo(self):
saldo_inicial = float(input("Ingresar el saldo inicial: "))

cajero1 = cajero(saldo_inicial)
# Out:
#   File "/tmp/ipython-input-1153480833.py", line 6
#     else:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4
