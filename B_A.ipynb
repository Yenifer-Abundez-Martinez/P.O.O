# %%
b= 0
a= 0

if type(b) is not int:
  raise Exception("Error Unicamente se permiten enteros")

elif b == 0:
    print("No se puede dividir entre el cero")

else:
    print(a/b)
    print(a/b)
# Out:
# No se puede dividir entre el cero
