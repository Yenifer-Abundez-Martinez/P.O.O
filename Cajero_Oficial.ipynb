# %%
class cajero:
  def __init__(self, saldo_inicial):
    if saldo_inicial > 10000:
      self.saldo = saldo_inicial
      print(f"Se asignó ${saldo_inicial} como saldo inicial.")
    else:
      self.saldo = 10001
      print("El saldo inicial debe ser mayor a $10,000. Se asignó $10,001 como saldo inicial.")

  def depositar(self, monto):
    if monto > 0:
      self.saldo += monto
      print(f"Depositaste ${monto}. Saldo actual: ${self.saldo}")
    else:
      print("El monto a depositar debe ser mayor a 0.")

  def retirar(self, monto):
    if monto <= 0:
      print("El monto a retirar debe ser mayor a 0.")
    elif self.saldo - monto < 10000:
      print("No se puede retirar esa cantidad. El saldo mínimo es de $10,000.")
    else:
      self.saldo -= monto
      print(f"Retiraste ${monto}. Saldo actual: ${self.saldo}")

  def mostrar_saldo(self):
    print(f"Su saldo actual es: ${self.saldo}")

def mostrar_saldo(self):
  saldo_inicial = float(input("Ingresa el saldo inicial: "))
  cuenta = cajero(saldo_inicial)

while True:
  print("\n--- Menú ---")
  print("1. Depositar")
  print("2. Retirar")
  print("3. Mostrar saldo")
  print("4. Salir")

  opcion = input("Selecciona una opción: ")

  if opcion == "1":
    cantidad = float(input("Ingresa el monto a depositar: "))
Cuenta.depositar(cantidad)

elif opcion == "2":
cantidad = float(input("Ingresa el monto a retirar: "))
cuenta.retirar(cantidad)

elif opcion == "3":
cuenta.mostrar_saldo()

elif opcion == "4":
print("¡Hasta luego!")
break

else:
print("Opción inválida, Por favor selecciona una opción válida.")
# Out:
#   File "/tmp/ipykernel_174/2438173465.py", line 46
#     elif opcion == "2":
#     ^
# SyntaxError: invalid syntax
